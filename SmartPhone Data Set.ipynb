# %% [markdown]
# <a href="https://github.com/koyarqasm/SmartPhone-dataset" target="_parent"><img src="https://cdn-icons-png.flaticon.com/512/25/25231.png" width="100px" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
#     <h1 style="color: #31708F; text-align:center; font-size:50px; font-weight: bolder;">SmartPhone Data Set</h1><br>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#         <p style="font-size:16px;">The dataset provides a structured overview of various smartphones available in the market, capturing crucial technical specifications and pricing information. This data can be used for comparative analysis, identifying trends in pricing based on specifications, and assessing market offerings by different brands.<br><br>
#
# Smartphone: The general category or identifier for the smartphone.<br>
# Brand: The manufacturer or brand name of the smartphone (e.g., Apple, Samsung, Xiaomi).<br>
# Model: The specific model or version of the smartphone (e.g., iPhone 12, Galaxy S21, Mi 11).<br>
# RAM: The amount of random access memory in the smartphone, usually measured in gigabytes (GB) (e.g., 4GB, 6GB, 8GB, 12GB).<br>
# Storage: The internal storage capacity of the smartphone, also typically measured in gigabytes (GB) (e.g., 64GB, 128GB, 256GB, 512GB).<br>
# Color: The color variant of the smartphone (e.g., Black, White, Blue).<br>
# Free: Likely a binary or categorical variable indicating whether the smartphone comes with some form of promotional offer, free accessory, or service (e.g., Yes/No or specific freebie details).<br>
# Final Price: The final selling price of the smartphone after any discounts or promotions, typically in a currency like USD.<br><br><br>
#
# </p>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Start</b></p>
# </div>

# %%
#Load necessary packages
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv('smartphones.csv') #to read our data set

# %%
mydata.head(10) #to show head
# Out:
#                                           Smartphone     Brand  \
# 0                 Realme C55 8/256GB Sunshower Libre    Realme
# 1           Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2       Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3           Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4            Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# 5               Motorola Moto E32s 4/64GB Gris Libre  Motorola
# 6            Nothing Phone (2) 12/256GB Blanco Libre   Nothing
# 7                Realme 9 Pro 5G 8/128GB Negro Libre    Realme
# 8          Samsung Galaxy M23 5G 4/128GB Verde Libre   Samsung
# 9  Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito ...    Xiaomi
#
#             Model   RAM  Storage   Color Free  Final Price
# 0             C55   8.0      256  Yellow  Yes       231.60
# 1      Galaxy M23   4.0      128    Blue  Yes       279.00
# 2        Moto G13   4.0      128    Blue  Yes       179.01
# 3  Redmi Note 11S   6.0      128    Gray  Yes       279.99
# 4       Phone (2)  12.0      512   White  Yes       799.00
# 5       Moto E32s   4.0       64    Gray  Yes       148.52
# 6       Phone (2)  12.0      256   White  Yes       699.00
# 7           9 Pro   8.0      128   Black  Yes       352.59
# 8      Galaxy M23   4.0      128   Green  Yes       279.00
# 9   Redmi Note 12   8.0      256    Gray  Yes       329.99

# %%
mydata.tail(10) #to show tail
# Out:
#                                           Smartphone    Brand          Model  \
# 489                  Realme 9 5G 4/128GB Negro Libre   Realme              9
# 490    Apple iPhone 12 Mini 256GB (PRODUCT)RED Libre    Apple      iPhone 12
# 491               Google Pixel 7 8/128GB Nieve Libre   Google        Pixel 7
# 492                 Apple iPhone 13 256GB Azul Libre    Apple      iPhone 13
# 493         Samsung Galaxy S23 Plus 256GB Lila Libre  Samsung     Galaxy S23
# 494  Xiaomi Redmi Note 12 Pro 5G 6/128GB Negro Libre   Xiaomi  Redmi Note 12
# 495        Samsung Galaxy A34 5G 6/128GB Verde Libre  Samsung     Galaxy A34
# 496              Apple iPhone 12 256GB Púrpura Libre    Apple      iPhone 12
# 497     OnePlus Nord N10 5G 6/128GB Azul Hielo Libre  OnePlus       Nord N10
# 498             Apple iPhone 12 Mini 64GB Azul Libre    Apple      iPhone 12
#
#      RAM  Storage   Color Free  Final Price
# 489  4.0      128   Black  Yes       282.58
# 490  NaN      256     Red  Yes       859.00
# 491  8.0      128   White  Yes       654.00
# 492  NaN      256    Blue  Yes      1029.00
# 493  NaN      256  Purple  Yes       893.00
# 494  6.0      128   Black  Yes       379.99
# 495  6.0      128   Green  Yes       299.90
# 496  NaN      256  Purple  Yes       979.00
# 497  6.0      128    Blue  Yes       219.00
# 498  NaN       64    Blue  Yes       689.00

# %%
mydata.columns #show columns
# Out:
# Index(['Smartphone', 'Brand', 'Model', 'RAM', 'Storage', 'Color', 'Free',
#        'Final Price'],
#       dtype='object')

# %%
mydata.info() #show info of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   499 non-null    object
#  1   Brand        499 non-null    object
#  2   Model        499 non-null    object
#  3   RAM          349 non-null    float64
#  4   Storage      499 non-null    int64
#  5   Color        499 non-null    object
#  6   Free         499 non-null    object
#  7   Final Price  499 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 31.3+ KB

# %%
mydata.describe() #to describe the data set
# Out:
#               RAM     Storage  Final Price
# count  349.000000  499.000000   499.000000
# mean     6.232092  179.531062   549.173607
# std      2.688952  117.201010   427.666601
# min      1.000000    2.000000    69.370000
# 25%      4.000000  128.000000   214.495000
# 50%      6.000000  128.000000   382.990000
# 75%      8.000000  256.000000   829.010000
# max     12.000000  512.000000  1919.000000

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Graph</b></p>
# </div>

# %%
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(5,5)) #size of the histogram
plt.show() #show histogram

# %%
mydata.hist(['RAM'], figsize=(5,5)) #histogram of age
plt.show() #show histogram

# %%
# Create a contingency table to show the frequency distribution of 'Size' across different 'Gender' categories
pd.crosstab(mydata['Brand'], mydata['RAM'])
# Out:
# RAM       1.0   2.0   3.0   4.0   6.0   8.0   12.0
# Brand
# Alcatel      2     2     0     0     0     0     0
# CAT          0     0     1     0     0     0     0
# Cubot        0     0     0     0     0     1     1
# Google       0     0     0     0     1     2     0
# Motorola     0     2     0     3     2    12     2
# Nothing      0     0     0     0     0     1     6
# OPPO         0     0     0     7     1    15     4
# OnePlus      0     0     0     0     2     1     0
# POCO         0     0     2     7    10    11     2
# Realme       0     0     4    12     4    13     5
# SPC          0     0     1     0     0     0     0
# Samsung      0     0     2    21    16    32     6
# TCL          0     5     1     8     2     0     0
# Ulefone      0     0     0     1     0     0     0
# Vivo         0     0     0     2     2     8     1
# Xiaomi       0     9    12    28    17    28     3
# ZTE          0     2     2     2     0     0     0

# %%
# Creates a cross-tabulation of gender and beverage orders
pd.crosstab(mydata['Brand'],mydata['Storage'] )
# Out:
# Storage   2    16   32   64   128  256  512
# Brand
# Alcatel     0    2    2    0    0    0    0
# Apple       0    0    0   17   43   28   16
# CAT         0    0    1    0    0    0    0
# Cubot       0    0    0    0    0    2    0
# Google      0    0    0    0    3    0    0
# Motorola    0    0    1    2    8   10    0
# Nothing     0    0    0    0    0    5    2
# OPPO        0    0    0    3   13   11    0
# OnePlus     0    0    0    0    3    0    0
# POCO        0    0    2    3   14   13    0
# Realme      0    0    4    6   17    9    2
# SPC         0    0    1    0    0    0    0
# Samsung     0    0    2    8   50   46   14
# TCL         1    0    3    8    3    2    0
# Ulefone     0    0    0    1    0    0    0
# Vivo        0    0    0    0    8    5    0
# Xiaomi      0    1    9   18   44   26    0
# ZTE         0    0    1    4    2    0    0

# %%
sns.pairplot(mydata) # Create a pair plot to visualize relationships between all numeric variables in the dataset
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p style="font-size:16px;"><b>Stander Deviation</b></p>
# </div>

# %%
mydata['RAM'].std() #stander deviation
# Out:
# 2.6889517319684324

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Mean</b></p>
# </div>

# %%
mydata['RAM'].mean() #mean
# Out:
# 6.232091690544412

# %%
# Create a histogram using histplot
sns.distplot(mydata['RAM'])
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_35000\1066996851.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mydata['RAM'])
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='RAM', ylabel='Density'>

# %%
# Create a histogram of 'Gender' grouped by 'Age' with a specified figure size
mydata.hist(by='Brand', column='RAM', figsize=(5, 5))
# Out:
# array([[<Axes: title={'center': 'Alcatel'}>,
#         <Axes: title={'center': 'Apple'}>,
#         <Axes: title={'center': 'CAT'}>,
#         <Axes: title={'center': 'Cubot'}>],
#        [<Axes: title={'center': 'Google'}>,
#         <Axes: title={'center': 'Motorola'}>,
#         <Axes: title={'center': 'Nothing'}>,
#         <Axes: title={'center': 'OPPO'}>],
#        [<Axes: title={'center': 'OnePlus'}>,
#         <Axes: title={'center': 'POCO'}>,
#         <Axes: title={'center': 'Realme'}>,
#         <Axes: title={'center': 'SPC'}>],
#        [<Axes: title={'center': 'Samsung'}>,
#         <Axes: title={'center': 'TCL'}>,
#         <Axes: title={'center': 'Ulefone'}>,
#         <Axes: title={'center': 'Vivo'}>],
#        [<Axes: title={'center': 'Xiaomi'}>,
#         <Axes: title={'center': 'ZTE'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Create separate histograms of 'Age' for each 'Gender' group
mydata.hist(by='Brand', column='Storage')
# Out:
# array([[<Axes: title={'center': 'Alcatel'}>,
#         <Axes: title={'center': 'Apple'}>,
#         <Axes: title={'center': 'CAT'}>,
#         <Axes: title={'center': 'Cubot'}>],
#        [<Axes: title={'center': 'Google'}>,
#         <Axes: title={'center': 'Motorola'}>,
#         <Axes: title={'center': 'Nothing'}>,
#         <Axes: title={'center': 'OPPO'}>],
#        [<Axes: title={'center': 'OnePlus'}>,
#         <Axes: title={'center': 'POCO'}>,
#         <Axes: title={'center': 'Realme'}>,
#         <Axes: title={'center': 'SPC'}>],
#        [<Axes: title={'center': 'Samsung'}>,
#         <Axes: title={'center': 'TCL'}>,
#         <Axes: title={'center': 'Ulefone'}>,
#         <Axes: title={'center': 'Vivo'}>],
#        [<Axes: title={'center': 'Xiaomi'}>,
#         <Axes: title={'center': 'ZTE'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15, 5))  # Adjust the width and height as needed

# Visualize the distribution of 'Age' across 'Beverage Ordered' categories using a box plot with adjusted width
sns.boxplot(x="Color", y="Final Price", data=mydata, width=0.5)
# Out:
# <Axes: xlabel='Color', ylabel='Final Price'>

# %% [markdown]
# ---

# %%
#Load necessary packages
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = mydata.Storage #to read age in our data set

# %%
#Print the values from 1 to 15 to check
x[1:15]
# Out:
# 1     128
# 2     128
# 3     128
# 4     512
# 5      64
# 6     256
# 7     128
# 8     128
# 9     256
# 10    128
# 11     64
# 12    256
# 13    256
# 14    256
# Name: Storage, dtype: int64

# %%
fig, ax = plt.subplots()
_ = plt.hist(x, color = '#0e730a') #create histogram for variable x in green color

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Mean</b></p>
# </div>

# %%
xbar = x.mean() #find mean
xbar
# Out:
# 179.5310621242485

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p style="font-size:16px;"><b>Figures</b></p>
# </div>

# %%
fig, ax = plt.subplots()
plt.axvline(x = x.mean(), color='orange') #show mean
_ = plt.hist(x, color = '#0e730a')

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Median</b></p>
# </div>

# %%
np.median(x) #find median
# Out:
# 128.0

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange') #show mean
plt.axvline(x = np.median(x), color='red') #show median
_ = plt.hist(x, color = '#0e730a')

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Variance</b></p>
# </div>

# %%
x.var() # Calculate the variance of the variable x
# Out:
# 13736.076844451914

# %%
x.var()**(1/2) # Calculate the standard deviation of the variable x
# Out:
# 117.2010104241935

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Stander Deviation</b></p>
# </div>

# %%
sigma = x.std() #find stander deviation
sigma
# Out:
# 117.2010104241935

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='orange') #mean
plt.axvline(x = xbar+(1.5*sigma), color='#0e730a') #xbar+(1.5*sigma)
plt.axvline(x = xbar+sigma, color='olivedrab') #sigma
plt.axvline(x = xbar-sigma, color='olivedrab') #sigma
plt.axvline(x = xbar-(1.5*sigma), color='#0e730a') #xbar-(1.5*sigma)
_ = plt.hist(x, color = 'lightgray') #x color

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Gaussian Distribution</b></p>
#     <p style="font-size:14px;">After Carl Friedrich Gauss. Also known as <b>normal distribution:</b></p>
# </div>

# %%
x = mydata.Storage #to read RAM in our data set

# %%
sns.set_style('ticks') #Set seaborn style to 'ticks'

# %%
_ = sns.displot(x, kde=True)
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x.mean() #find mean
# Out:
# 179.5310621242485

# %%
x.std() #find stander deviation
# Out:
# 117.2010104241935

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p style="font-size:16px;"><b>The Central Limit Theorem</b></p>
# </div>

# %%
# Generate a random sample of 20 elements from array x with replacement
x_sample = np.random.choice(x, size=15, replace=True)
x_sample
# Out:
# array([ 32, 128, 128, 128, 128,  64, 256, 256, 256, 128, 128, 256,  32,
#        128, 256], dtype=int64)

# %%
# Calculate the mean of the sample 'x_sample'
x_sample.mean()
# Out:
# 153.6

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Sampling Distributions</b></p>
# </div>

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=True)
        sample_means.append(sample.mean())
    return sample_means

# %%
sample_means = sample_mean_calculator(x, 10, 1000)  # Calculate sample means
sns.displot(data=sample_means, color='green', kde=True)  # Plot the distribution
_ = plt.xlim(50, 350)  # Set the x-axis limits
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(sample_mean_calculator(x, 10, 100), color='green', kde=True)
_ = plt.xlim(50, 350)  # Set the x-axis limits
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(sample_mean_calculator(x, 100, 1000), color='green', kde=True)
_ = plt.xlim(50, 350)  # Set the x-axis limits
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Sampling from a skewed distribution</b></p>
# </div>

# %%
s = st.skewnorm.rvs(10, size=10000)

# %%
_ = sns.displot(s, kde=True)
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
_ = sns.displot(sample_mean_calculator(s, 10, 1000), color='green', kde=True)
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(sample_mean_calculator(x, 20, 500), color='red', kde=True)  # Create a distribution plot of sample means using seaborn, with a red color and KDE overlay
_ = plt.xlim(50, 350)  # Set the x-axis limits
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p style="font-size:16px;"><b>Sampling from a multimodal distribution</b></p>
# </div>

# %%
# Generate random samples from a skewed normal distribution
s = st.skewnorm.rvs(10, size=10000)

# Create a distribution plot with KDE using seaborn
_ = sns.displot(s, kde=True)
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Concatenate two normal distributions and plot their distribution with KDE using seaborn
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc=4.0, size=1000)))
_ = sns.displot(m, kde=True)
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Concatenate three normal distributions and plot their distribution with KDE using seaborn
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc=4.0, size=2000), np.random.normal(loc=8.0, size=1000)))
_ = sns.displot(m, kde=True)

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p style="font-size:16px;"><b>Sampling from Uniform</b></p>
# </div>

# %%
# Assign the 'Age' column of the DataFrame 'mydata' to variable 'u'
u = mydata.Storage

# %%
# Plot the distribution of 'u' using seaborn
_ = sns.displot(u)
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p style="font-size:16px;"><b>Z-Scores</b></p>
# </div>

# %%
# Assign the 'Age' column of the DataFrame 'mydata' to variable 'x'
x = mydata.Storage

# %%
# Assign values to variables: x_i = 20, mu = 33.5, sigma = 5
x_i = 128
mu = x.mean()
sigma = x.std()

# %%
sns.displot(x, color='gray') # Plot a distribution plot of the variable x in gray color
ax.set_xlim(0, 100) # Set the x-axis limit of the plot
plt.axvline(mu, color='orange') # Add a vertical line at the mean (mu) in orange color
# Add vertical lines at mu ± 1, and 2 standard deviations (sigma) in olivedrab color
for v in [-2, -1, 1, 2]:
    plt.axvline(mu + v * sigma, color='olivedrab')
_ = plt.axvline(x_i, color='red') # Add a vertical line at x_i (a specific value) in color 'red'
# Out:
# D:\Programs\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ***

# %%
# Calculate the z-score using the formula: z = (x_i - mu) / sigma
z = (x_i - mu) / sigma
z
# Out:
# -0.4396810397601409

# %%
# Calculate the z-score using the formula: z = (x_i - mean(x)) / std(x)
z = (x_i - np.mean(x)) / np.std(x)
z
# Out:
# -0.4401222651995773

# %%
# Count the number of elements in array 'x' that are greater than the threshold x_i
count = len(np.where(x > x_i)[0])

# %%
# Calculate the percentage using the formula: percentage = (count_greater_than_xi * 100) / total elements in x
(count * 100) / len(x)
# Out:
# 38.276553106212425

# %%
# Calculate the 99th percentile of array 'x'
np.percentile(x, 99)
# Out:
# 50.0

# %%
# Assign values to variables: mu = 90, sigma = 2
mu = 90
sigma = 2

# %%
# Generate 10,000 random samples from a normal distribution with mean 'mu' and standard deviation 'sigma'
y = np.random.normal(mu, sigma, 100)

# %%
sns.displot(y, color='gray')  # Plot a distribution plot of the variable y in gray color
plt.axvline(mu, color='orange')  # Add a vertical line at the mean (mu) in orange color
for v in [-2, -1, 1, 2]: # Add vertical lines at mu ± 1 and 2 standard deviations (sigma) in olivedrab color
    plt.axvline(mu + v * sigma, color='olivedrab')  
_ = plt.axvline(mu, color='#31708F')  # Add a vertical line at mu (a specific value) in purple color

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style="font-size:16px;"><b>Penguins</b></p>
# </div>

# %%
penguins = sns.load_dataset('penguins').dropna() # some rows are missing data

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
# Get unique species and their counts from the penguins dataset
np.unique(penguins.species, return_counts=True)
# Out:
# (array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object),
#  array([146,  68, 119], dtype=int64))

# %%
Chinstrap = penguins[penguins.species == 'Chinstrap']

# %%
Chinstrap
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Chinstrap  Dream            46.5           17.9              192.0
# 153  Chinstrap  Dream            50.0           19.5              196.0
# 154  Chinstrap  Dream            51.3           19.2              193.0
# 155  Chinstrap  Dream            45.4           18.7              188.0
# 156  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 152       3500.0  Female
# 153       3900.0    Male
# 154       3650.0    Male
# 155       3525.0  Female
# 156       3725.0    Male
# ..           ...     ...
# 215       4000.0    Male
# 216       3400.0  Female
# 217       3775.0    Male
# 218       4100.0    Male
# 219       3775.0  Female
#
# [68 rows x 7 columns]

# %%
np.unique(Chinstrap.island, return_counts=True)
# Out:
# (array(['Dream'], dtype=object), array([68], dtype=int64))

# %%
np.unique(Chinstrap.sex, return_counts=True)
# Out:
# (array(['Female', 'Male'], dtype=object), array([34, 34], dtype=int64))

# %%
_ = sns.boxplot(x='island', y='body_mass_g', hue='sex', data=Chinstrap)

# %%
fem = Chinstrap[Chinstrap.sex == 'Female']['body_mass_g'].to_numpy()/1000
fem
# Out:
# array([3.5  , 3.525, 3.95 , 3.25 , 4.15 , 3.8  , 3.7  , 3.575, 3.7  ,
#        3.45 , 3.6  , 2.9  , 3.3  , 3.4  , 3.7  , 3.2  , 3.35 , 3.9  ,
#        3.85 , 2.7  , 3.65 , 3.5  , 3.675, 3.4  , 3.675, 3.325, 3.6  ,
#        3.35 , 3.25 , 3.525, 3.65 , 3.65 , 3.4  , 3.775])

# %%
mal = Chinstrap[Chinstrap.sex == 'Male']['body_mass_g'].to_numpy()/1000
mal
# Out:
# array([3.9  , 3.65 , 3.725, 3.75 , 3.7  , 3.775, 4.05 , 4.05 , 3.3  ,
#        4.4  , 3.4  , 3.8  , 4.15 , 3.8  , 4.55 , 4.3  , 4.1  , 3.6  ,
#        4.8  , 4.5  , 3.95 , 3.55 , 4.45 , 4.3  , 3.25 , 3.95 , 4.05 ,
#        3.45 , 4.05 , 3.8  , 3.95 , 4.   , 3.775, 4.1  ])

# %%
fbar = fem.mean()
fbar
# Out:
# 3.5272058823529413

# %%
mbar = mal.mean()
mbar
# Out:
# 3.9389705882352937
